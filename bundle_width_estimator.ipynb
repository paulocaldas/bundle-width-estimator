# %% [markdown]
# ## bundle width estimation using Eucledian Distance Mapping (EDM)

# %%
# specify path_to_file/filename.tif 
filename = 'movie_example/bundles_examples.tif'

# import all functions for analysis
from bkg_func import bundle_width_estimator_script as EDM

# run analysis for a time-lapse movie
EDM.analyze_movie(filename, time_per_frame = 2, cutoff = -1, step = 1, 
                  pixel_size = 0.108, show_images = True, save_files  = False);
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Processing ...')

# %% [markdown]
# <hr>
